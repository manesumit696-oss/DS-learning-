# %%
price = 1000
discount = 0.2
tax = 0.12
final_price = price-(price*discount)
fin_price = final_price+(final_price*tax)
print("final price:",final_price)
print("final price after discount:",fin_price)
# Out:
# final price: 800.0
# final price after discount: 896.0

# %%
customer_name ="Ankita"
age = 18
salary = 55000.75
is_false = False
print(type(customer_name))
print(type(age))
print(type(salary))
print(type(is_false))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %%
item1 = 1200
item2 = 800
item3 = 600
discount = 0.1
gst = 0.18
total= item1+item2+item3
final_bill = total-(total*discount)

total_bill = final_bill+(final_bill*gst)
print("new total final bill after gst:",total_bill)
print("total bill:",total)
print("total bill after discount:",final_bill)
# Out:
# new total final bill after gst: 2761.2
# total bill: 2600
# total bill after discount: 2340.0

# %%
age = 20
salary = 55000.0
loan_amount = 0 # You can replace 0 with any other default or actual value

# %%
marks=int(input("enter your score:"))
if marks>=95:
  print("grade O(outstanding)")
elif marks>=90:
  print("grade A+(excellent)")
elif marks>=85:
  print("grade A(good)")
elif marks>=75:
  print("grade B(average)")
elif marks>=50:
  print("grade C(needs improvement)")
else:
  print("grade D(fail)")
# Out:
# enter your score:100
# grade O(outstanding)

# %%
customers = ["Himmat","Aryan","Sumit","Sushant","Harsh"]
for names in customers:
  print("Sending email to:",names)
# Out:
# Sending email to: Himmat
# Sending email to: Aryan
# Sending email to: Sumit
# Sending email to: Sushant
# Sending email to: Harsh

# %%
for i in range (1,6):
  print("remainder email number:",i)
# Out:
# remainder email number: 1
# remainder email number: 2
# remainder email number: 3
# remainder email number: 4
# remainder email number: 5

# %%
students = {"rahul":85,"priya":92,"amit":74}

for name, marks in students.items():

  if marks >=90:
    grade = "A"

  elif  marks >=70:
    grade = "B"


  else:
    grade= "C"
  print(f"Student:{name},marks: {marks},Grade,{grade}")
# Out:
# Student:rahul,marks: 85,Grade,B
# Student:priya,marks: 92,Grade,A
# Student:amit,marks: 74,Grade,B

# %%
def great(name):
  print("name",name,"welcome to the bootcamp!")

great("sumit")

def hello(name):
  print("mad",name,"welcome to the bootcamp!")

hello("rishi")
# Out:
# name sumit welcome to the bootcamp!
# mad rishi welcome to the bootcamp!

# %%
def Money(z,y,x):
  total=x+y
  return total
print(Money(1000,5000,3000))
print(Money("abc","xyz","123"))
# Out:
# 8000
# 123xyz

# %%
def eligiblity(age):
  if age>=18:
    print("eligible")
  else:
    print("not eligible")
eligiblity(15)
# Out:
# not eligible

# %%
price=1000
discount=0.2
final_price=price-(price*discount)
final_tax=final_price+(final_price*0.18)
print("Final price of the discount:",final_tax)
# Out:
# Final price of the discount: 944.0

# %%
final_tax=final_price+(final_price*0.12)
print("Final price of the discount:",final_tax)
# Out:
# Final price of the discount: 896.0

# %%
Customer_name = "Rahul"
age = 25
salary = 55000.75
is_fraud = False
print(type(Customer_name))
print(type(age))
# Out:
# <class 'str'>
# <class 'int'>

# %%
age = 30
salary = 55000.0
loan_amount = 200000
existing_loan = 2
credit_score = 720
is_citizen = True

emi = loan_amount / 24
total_income_yearly = salary*12
remaining_salary = total_income_yearly - (emi*12)

print("Monthly EMI:", emi)
print("Yearly Income:",total_income_yearly)
print("Remaining salary after EMI:",remaining_salary)
# Out:
# Monthly EMI: 8333.333333333334
# Yearly Income: 660000.0
# Remaining salary after EMI: 560000.0

# %%
item1=1200
item2=800
item3=600
discount=0.1

total=item1+item2+item3
final_bill=total-(total*discount)

print("Total Bill:",total)
print("Final Bill after discount:",final_bill)
# Out:
# Total Bill: 2600
# Final Bill after discount: 2340.0

# %%
marks=int(input("Enter your score:"))

if marks >= 90:
  print("Grade: A (Excellent!)")
elif marks >= 75:
  print("Grade: B (Good)")
else:
  print("Grade: C (Needs Improvement)")
# Out:
# Enter your score:100
# Grade: A (Excellent!)

# %%
marks=int(input("Enter the score:"))
if marks>95:
  print("GRADE:A+(OUTSTANDING)")
elif marks>90:
  print("GRADE:A(Excellent)")
elif marks>75:
  print("GRADE:B(Good)")
elif marks>60:
  print("GRADE:C(NEED IMPROVEMENT)")
else:
  print("GRADE:D(FAIL)")
# Out:
# Enter the score:100
# GRADE:A+(OUTSTANDING)

# %%
customer = ["Rahul","Priya","Amit","Sneha","Vikram"]

for name in customer:
  print("Sending email to:",name)
# Out:
# Sending email to: Rahul
# Sending email to: Priya
# Sending email to: Amit
# Sending email to: Sneha
# Sending email to: Vikram

# %%
for i in range(1,6):
  print("Remaining email number:",i)
# Out:
# Remaining email number: 1
# Remaining email number: 2
# Remaining email number: 3
# Remaining email number: 4
# Remaining email number: 5

# %%
students = {"Rahul": 85,"priya": 92,"Amit": 74}

for name,marks in students.items():
  if marks >= 90:
    grade = "A"
  elif marks >= 75:
    grade = "B"
  else:
    grade = "C"
  print(f"Student: {name}, Marks: {marks}, Grade: {grade}")
# Out:
# Student: Rahul, Marks: 85, Grade: B
# Student: priya, Marks: 92, Grade: A
# Student: Amit, Marks: 74, Grade: C

# %%
def greet(name):
  print("Hello",name,"welcome to the Bootcamp")

greet("Rahul")
greet("Priya")
# Out:
# Hello Rahul welcome to the Bootcamp
# Hello Priya welcome to the Bootcamp

# %%
def money(x,y):
  total=x+y
  return total
money(1000,2000)
money("abc","xyz")
# Out:
# 'abcxyz'

# %%
def calculate_discount(price, discount_percent):
    return price - (price * discount_percent / 100)

def apply_tax(price, tax_percent):
    return price + (price * tax_percent / 100)

price = 1000
discounted_price = calculate_discount(price, 10)
final_price = apply_tax(discounted_price, 18)
print("Final price after discount and tax:", final_price)
# Out:
# Final price after discount and tax: 1062.0

# %%
def issue_books(student_name, books):
    print(f"\n {student_name} borrowed:")
    for book in books:
        print("_", book)

def calculate_fine(days_late):
    fine_per_day = 5
    return days_late * fine_per_day

def student_report(student_name, books, days_late):
    issue_books(student_name, books)
    fine = calculate_fine(days_late)
    print(f"Fine to be paid: ₹{fine}\n")

student_report("Rahul", ["Python Bricks", "Data Science 101"], 3)
student_report("Priya", ["Machine learning"], 0)
# Out:
#  Rahul borrowed:
# _ Python Bricks
# _ Data Science 101
# Fine to be paid: ₹15
#
#
#  Priya borrowed:
# _ Machine learning
# Fine to be paid: ₹0
